# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib ipympl
import sys

import hydra
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import torch
import torchaudio
import lightning.pytorch as pl
from scipy.stats import gaussian_kde
from omegaconf import OmegaConf
import matplotlib.pyplot as plt
import numpy as np


from IPython.display import Audio, display

from pathlib import Path
from egaznepy.visualize import apply_plot_style
from src.data.mocha_timit_datamodule import MTIMITDataModule
from src.models.pitch_module import PitchModule
from src.models.components.metrics import RCAMetric
from torchmetrics.classification.accuracy import Accuracy



apply_plot_style(0.9)
plt.rcParams['text.usetex'] = False

root_dir = Path(globals()['_dh'][0]).parent
print(root_dir)
import os
os.chdir(root_dir)
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

config_path_predict_cc = 'logs/train/runs/2024-07-23_15-17-46_cc_timit_with_reduced_cc/.hydra/config.yaml'
ckpt_path_cc = 'logs/train/runs/2024-07-23_15-17-46_cc_timit_with_reduced_cc/checkpoints/epoch_010.ckpt'
# Out:
# /dataHDD/chsaikeerthi/2024-chirumamilla

# %%
config_predict_cc = OmegaConf.load(config_path_predict_cc)
datamodule = hydra.utils.instantiate(config_predict_cc.data, slice=False, batch_size=4)
pitch_module_cc: PitchModule = hydra.utils.instantiate(config_predict_cc.model)

del config_predict_cc.trainer.default_root_dir

config_predict_cc.trainer.limit_predict_batches = 1

trainer = hydra.utils.instantiate(config_predict_cc.trainer) 
arr_predict_cc = trainer.predict(model=pitch_module_cc, datamodule=datamodule, ckpt_path=ckpt_path_cc)
# Out:
# /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:199: Attribute 'extractor' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['extractor'])`.
# /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:199: Attribute 'encoder' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['encoder'])`.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_predict_batches=1)` was configured so 1 batch will be used.
# /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:44: attribute 'extractor' removed from hparams because it cannot be pickled
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py:306, in _lazy_init()
#     305 try:
# --> 306     queued_call()
#     307 except Exception as e:
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py:174, in _check_capability()
#     173 for d in range(device_count()):
# --> 174     capability = get_device_capability(d)
#     175     major = capability[0]
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py:430, in get_device_capability(device)
#     418 r"""Get the cuda capability of a device.
#     419
#     420 Args:
#    (...)
#     428     tuple(int, int): the major and minor cuda capability of the device
#     429 """
# --> 430 prop = get_device_properties(device)
#     431 return prop.major, prop.minor
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py:448, in get_device_properties(device)
#     447     raise AssertionError("Invalid device id")
# --> 448 return _get_device_properties(device)
#
# RuntimeError: device >= 0 && device < num_gpus INTERNAL ASSERT FAILED at "/opt/conda/conda-bld/pytorch_1712608935911/work/aten/src/ATen/cuda/CUDAContext.cpp":50, please report a bug to PyTorch. device=, num_gpus=
#
# The above exception was the direct cause of the following exception:
#
# DeferredCudaCallError                     Traceback (most recent call last)
# Cell In[2], line 10
#       7 config_predict_cc.trainer.limit_predict_batches = 1
#       9 trainer = hydra.utils.instantiate(config_predict_cc.trainer)
# ---> 10 arr_predict_cc = trainer.predict(model=pitch_module_cc, datamodule=datamodule, ckpt_path=ckpt_path_cc)
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:864, in Trainer.predict(self, model, dataloaders, datamodule, return_predictions, ckpt_path)
#     862 self.state.status = TrainerStatus.RUNNING
#     863 self.predicting = True
# --> 864 return call._call_and_handle_interrupt(
#     865     self, self._predict_impl, model, dataloaders, datamodule, return_predictions, ckpt_path
#     866 )
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/lightning/pytorch/trainer/call.py:44, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      42     if trainer.strategy.launcher is not None:
#      43         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 44     return trainer_fn(*args, **kwargs)
#      46 except _TunerExitException:
#      47     _call_teardown_hook(trainer)
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:903, in Trainer._predict_impl(self, model, dataloaders, datamodule, return_predictions, ckpt_path)
#     899 assert self.state.fn is not None
#     900 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     901     self.state.fn, ckpt_path, model_provided=model_provided, model_connected=self.lightning_module is not None
#     902 )
# --> 903 results = self._run(model, ckpt_path=ckpt_path)
#     905 assert self.state.stopped
#     906 self.predicting = False
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:943, in Trainer._run(self, model, ckpt_path)
#     939 # ----------------------------
#     940 # SET UP THE TRAINER
#     941 # ----------------------------
#     942 log.debug(f"{self.__class__.__name__}: setting up strategy environment")
# --> 943 self.strategy.setup_environment()
#     944 self.__setup_profiler()
#     946 log.debug(f"{self.__class__.__name__}: preparing data")
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/lightning/pytorch/strategies/strategy.py:129, in Strategy.setup_environment(self)
#     122 """Setup any processes or distributed connections.
#     123
#     124 This is called before the LightningModule/DataModule setup hook which allows the user to access the accelerator
#     125 environment before setup is complete.
#     126
#     127 """
#     128 assert self.accelerator is not None
# --> 129 self.accelerator.setup_device(self.root_device)
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/lightning/pytorch/accelerators/cuda.py:46, in CUDAAccelerator.setup_device(self, device)
#      44 if device.type != "cuda":
#      45     raise MisconfigurationException(f"Device should be GPU, got {device} instead")
# ---> 46 _check_cuda_matmul_precision(device)
#      47 torch.cuda.set_device(device)
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/lightning/fabric/accelerators/cuda.py:361, in _check_cuda_matmul_precision(device)
#     359 @lru_cache(1)  # show the warning only ever once
#     360 def _check_cuda_matmul_precision(device: torch.device) -> None:
# --> 361     if not torch.cuda.is_available() or not _is_ampere_or_later(device):
#     362         return
#     363     # check that the user hasn't changed the precision already, this works for both `allow_tf32 = True` and
#     364     # `set_float32_matmul_precision`
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/lightning/fabric/accelerators/cuda.py:355, in _is_ampere_or_later(device)
#     354 def _is_ampere_or_later(device: Optional[torch.device] = None) -> bool:
# --> 355     major, _ = torch.cuda.get_device_capability(device)
#     356     return major >= 8
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py:430, in get_device_capability(device)
#     417 def get_device_capability(device: Optional[_device_t] = None) -> Tuple[int, int]:
#     418     r"""Get the cuda capability of a device.
#     419
#     420     Args:
#    (...)
#     428         tuple(int, int): the major and minor cuda capability of the device
#     429     """
# --> 430     prop = get_device_properties(device)
#     431     return prop.major, prop.minor
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py:444, in get_device_properties(device)
#     434 def get_device_properties(device: _device_t) -> _CudaDeviceProperties:
#     435     r"""Get the properties of a device.
#     436
#     437     Args:
#    (...)
#     442         _CudaDeviceProperties: the properties of the device
#     443     """
# --> 444     _lazy_init()  # will define _get_device_properties
#     445     device = _get_device_index(device, optional=True)
#     446     if device < 0 or device >= device_count():
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py:312, in _lazy_init()
#     307         except Exception as e:
#     308             msg = (
#     309                 f"CUDA call failed lazily at initialization with error: {str(e)}\n\n"
#     310                 f"CUDA call was originally invoked at:\n\n{''.join(orig_traceback)}"
#     311             )
# --> 312             raise DeferredCudaCallError(msg) from e
#     313 finally:
#     314     delattr(_tls, "is_initializing")
#
# DeferredCudaCallError: CUDA call failed lazily at initialization with error: device >= 0 && device < num_gpus INTERNAL ASSERT FAILED at "/opt/conda/conda-bld/pytorch_1712608935911/work/aten/src/ATen/cuda/CUDAContext.cpp":50, please report a bug to PyTorch. device=, num_gpus=
#
# CUDA call was originally invoked at:
#
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_3235886/3205918903.py", line 10, in <module>
#     import torch
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/__init__.py", line 1478, in <module>
#     _C._initExtension(manager_path())
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py", line 238, in <module>
#     _lazy_call(_check_capability)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py", line 235, in _lazy_call
#     _queued_calls.append((callable, traceback.format_stack()))

# %%
batch = next(iter(datamodule.train_dataloader()))
x, y_pitch, y_prob = batch
features = pitch_module_cc.extract_features(x)
features_np = features.cpu().numpy()
plt.figure(figsize=(12, 6))
for i in range(features_np.shape[0]):  # iterate over batch dimension
    plt.subplot(features_np.shape[0], 1, i+1)
    plt.plot(features_np[i].flatten())  # flatten if features have more than 1 dimension
    plt.title(f'Feature Map for Sample {i+1}')
    plt.xlabel('Feature Index')
    plt.ylabel('Value')

plt.tight_layout()
plt.show()
# Out:
# Test dataloader
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py:306, in _lazy_init()
#     305 try:
# --> 306     queued_call()
#     307 except Exception as e:
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py:174, in _check_capability()
#     173 for d in range(device_count()):
# --> 174     capability = get_device_capability(d)
#     175     major = capability[0]
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py:430, in get_device_capability(device)
#     418 r"""Get the cuda capability of a device.
#     419
#     420 Args:
#    (...)
#     428     tuple(int, int): the major and minor cuda capability of the device
#     429 """
# --> 430 prop = get_device_properties(device)
#     431 return prop.major, prop.minor
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py:448, in get_device_properties(device)
#     447     raise AssertionError("Invalid device id")
# --> 448 return _get_device_properties(device)
#
# RuntimeError: device >= 0 && device < num_gpus INTERNAL ASSERT FAILED at "/opt/conda/conda-bld/pytorch_1712608935911/work/aten/src/ATen/cuda/CUDAContext.cpp":50, please report a bug to PyTorch. device=, num_gpus=
#
# The above exception was the direct cause of the following exception:
#
# DeferredCudaCallError                     Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 batch = next(iter(datamodule.train_dataloader()))
#       2 x, y_pitch, y_prob = batch
#       3 features = pitch_module_cc.extract_features(x)
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:434, in DataLoader.__iter__(self)
#     432 if self.persistent_workers and self.num_workers > 0:
#     433     if self._iterator is None:
# --> 434         self._iterator = self._get_iterator()
#     435     else:
#     436         self._iterator._reset(self)
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:387, in DataLoader._get_iterator(self)
#     385 else:
#     386     self.check_worker_number_rationality()
# --> 387     return _MultiProcessingDataLoaderIter(self)
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1055, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1053     current_device = custom_device_mod.current_device()
#    1054 else:
# -> 1055     current_device = torch.cuda.current_device()  # choose cuda for default
#    1056 pin_memory_thread = threading.Thread(
#    1057     target=_utils.pin_memory._pin_memory_loop,
#    1058     args=(self._worker_result_queue, self._data_queue,
#    1059           current_device,
#    1060           self._pin_memory_thread_done_event, self._pin_memory_device))
#    1061 pin_memory_thread.daemon = True
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py:778, in current_device()
#     776 def current_device() -> int:
#     777     r"""Return the index of a currently selected device."""
# --> 778     _lazy_init()
#     779     return torch._C._cuda_getDevice()
#
# File /dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py:312, in _lazy_init()
#     307         except Exception as e:
#     308             msg = (
#     309                 f"CUDA call failed lazily at initialization with error: {str(e)}\n\n"
#     310                 f"CUDA call was originally invoked at:\n\n{''.join(orig_traceback)}"
#     311             )
# --> 312             raise DeferredCudaCallError(msg) from e
#     313 finally:
#     314     delattr(_tls, "is_initializing")
#
# DeferredCudaCallError: CUDA call failed lazily at initialization with error: device >= 0 && device < num_gpus INTERNAL ASSERT FAILED at "/opt/conda/conda-bld/pytorch_1712608935911/work/aten/src/ATen/cuda/CUDAContext.cpp":50, please report a bug to PyTorch. device=, num_gpus=
#
# CUDA call was originally invoked at:
#
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_3234114/3538794329.py", line 10, in <module>
#     import torch
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/__init__.py", line 1478, in <module>
#     _C._initExtension(manager_path())
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py", line 238, in <module>
#     _lazy_call(_check_capability)
#   File "/dataHDD/chsaikeerthi/2024-chirumamilla/myenv/lib/python3.10/site-packages/torch/cuda/__init__.py", line 235, in _lazy_call
#     _queued_calls.append((callable, traceback.format_stack()))
